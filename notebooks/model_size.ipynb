# %%
import sys
sys.path.append('/home/smedar/code_files/vision-transformer')

# %%
from model import VisionTransformer

# %%
model = VisionTransformer()

# %%
sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
# 21_376_228
